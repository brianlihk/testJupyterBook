# %% [markdown]
# # Chart.js with Jupyter book - 2
#
# ## Testing on javascript and ipywidget
#
# ### Attempt 2

# %%
import ipywidgets as ui
from IPython.core.display import display, HTML

# Use IPython's HTML for the script
my_script = HTML("""
    <script>
        count = 0;
        widget = document.getElementById("tester-p");
        console.log(widget);
        widget.innerHTML = count;
    </script>

""")

display(my_script)

# Use ipywidgets HTML for the widget
text = ui.HTML("<p id='tester-p'>Hello World!</p>")   
display(text)
# Out:
# /var/folders/6y/wj224kz14r7fmfq5j9h9y9pr0000gn/T/ipykernel_19263/1926814118.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <script>
#     count = 0;
#     widget = document.getElementById("tester-p");
#     console.log(widget);
#     widget.innerHTML = count;
# </script>
# HTML(value="<p id='tester-p'>Hello World!</p>")

# %% [markdown]
# Still, IPython core is rendered before ipywidgets even we changed the order in script.
#
# ### Attempt 3

# %%
from IPython.core.display import display, HTML

text = HTML("<p id='tester-p'>Hello World!</p>")   
display(text)

my_script = HTML("""
    <script>
        count = 0;
        widget = document.getElementById("tester-p");
        console.log(widget);
        widget.innerHTML = count;
    </script>

""")

display(my_script)
# Out:
# /var/folders/6y/wj224kz14r7fmfq5j9h9y9pr0000gn/T/ipykernel_19263/2041957232.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <p id='tester-p'>Hello World!</p>
# <script>
#     count = 0;
#     widget = document.getElementById("tester-p");
#     console.log(widget);
#     widget.innerHTML = count;
# </script>

# %% [markdown]
# Pure IPython core is used, and the result is shown flawlessly.
#
# ### Attempt 4

# %%
from IPython.core.display import display, HTML

text = HTML("<p id='tester-p'>Hello World!</p>")
button = HTML("<button id='btn' onClick='changeDigit()'>Change</button>")
display(text)
display(button)

my_script = HTML("""
    <script>
        var count = 0;
        function changeDigit(){
          widget = document.getElementById("tester-p");
          console.log(widget);
          count++;
          widget.innerHTML = count;
        }
    </script>

""")

display(my_script)
# Out:
# /var/folders/6y/wj224kz14r7fmfq5j9h9y9pr0000gn/T/ipykernel_19263/466511866.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <p id='tester-p'>Hello World!</p>
# <button id='btn' onClick='changeDigit()'>Change</button>
# <script>
#     var count = 0;
#     function changeDigit(){
#       widget = document.getElementById("tester-p");
#       console.log(widget);
#       count++;
#       widget.innerHTML = count;
#     }
# </script>

# %% [markdown]
# The function is working and verified from console, but the innerHTML didn't change.
#
# ### Attempt 5

# %%
from IPython.core.display import display, HTML

text = HTML("<p id='atm4p'>Hello World!</p>")
button = HTML("<button id='btn' onClick='changeDigit()'>Change</button>")
display(text)
display(button)

my_script = HTML("""
    <script>
        var count = 0;
        function changeDigit(){
          widget = document.getElementById("atm4p");
          console.log(widget);
          count++;
          widget.innerHTML = count;
        }
    </script>

""")

display(my_script)
# Out:
# /var/folders/6y/wj224kz14r7fmfq5j9h9y9pr0000gn/T/ipykernel_19263/2478301387.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <p id='atm4p'>Hello World!</p>
# <button id='btn' onClick='changeDigit()'>Change</button>
# <script>
#     var count = 0;
#     function changeDigit(){
#       widget = document.getElementById("atm4p");
#       console.log(widget);
#       count++;
#       widget.innerHTML = count;
#     }
# </script>

# %% [markdown]
# Attemp 4 failed because it has shared the same pid with attemp 3. The issue was fixed by change the pid.
